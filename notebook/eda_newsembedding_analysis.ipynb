# %%
import os
import pandas as pd

# %%
pqfile = r"L:\MED\TRAN\2025_BankRegDataCollection\rtrs_news\2011-06_3PTY_ko.sentiment.parquet"

# %%
df = pd.read_parquet(pqfile)

# %%
df.shape
# Out:
# (5, 6)

# %%
df.head(2)
# Out:
#      index                     headline sentiment  \
# 0  1028178  손잡은 두 해커집단 "전세계 정부기관 공격하겠다"  negative
# 1   137719  亞경제도 `소프트패치` 국면..펀더멘털은 `튼튼`   neutral
#
#                                        justification  \
# 0  Cyberattacks targeting government and financia...
# 1  아시아 경제 성장 둔화에도 불구하고 펀더멘털이 튼튼하다는 평가로, 단기적 시장 영향...
#
#                               related_industry_naics related_company_names
# 0  ["511210 - Software Publishers","541511 - Cust...                    []
# 1  ["334413 - Semiconductor and Related Device Ma...                    []

# %%
df.sentiment.value_counts()
# Out:
# sentiment
# neutral     4
# negative    1
# Name: count, dtype: int64

# %%
df[df.sentiment == 'very negative']
# Out:
#         index                                        headline      sentiment  \
# 62    1197825        석유공사, 대왕고래에 10년간 탐사 시추비 60% 쏟아…회수액은 ‘0원’  very negative
# 75     123412                [AI시그널] 세동, 기술적 분석에 따른 하락세 지속 경고  very negative
# 112    550683             김정은, 신형 구축함 최현호 참관…"주체적 무장력 발전의 증시"  very negative
# 159     99068                     성폭행·담배빵 당한 여고생의 사망…학교도 외면했다  very negative
# 184   1723367  트레저글로벌(TGL), 2025년 연례 보고서 제출 및 경영진 보상 회수 정책 발표  very negative
# 259   1154862               캄보디아 쓰레기통서 '이것' 발견...네티즌 "무섭다" 충격  very negative
# 320   1259111     캄보디아 선교사 “올해만 50명 구조…최근엔 ‘서류 전달’·‘관광’으로 유인”  very negative
# 466    195711                  한 주 사이 '반토막'…DI동일에 무슨 일이[주톡피아]  very negative
# 603   1258280         숏폼 찍자며 접근…15세 소녀 성폭행한 '430만 유튜버' 아빠와 아들  very negative
# 732   1951317                거래소 “인피니트헬스케어, 상장적격성 실질심사 사유 발생”  very negative
# 801   1312196             "조건만남으로 돈 벌 수 있어"…10대 여학생 유인해 마약 투약  very negative
# ...
