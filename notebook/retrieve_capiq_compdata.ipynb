# %%
import os
import pandas as pd

from tqdm import tqdm
from sqlalchemy import create_engine, schema, Table, text, tuple_

# %%
DATABASE_DRIVER = "ODBC Driver 17 for SQL Server"
DATABASE_SERVER_INSTANCE = "MSAPSQL145.bisad.bisinfo.org,55001"
DATABASE_NAME = "capital_iq_data"

conn_str = f"mssql+pyodbc://{DATABASE_SERVER_INSTANCE}/{DATABASE_NAME}?driver={DATABASE_DRIVER}"

# %%
con_mssql = create_engine(conn_str)

# %%
qry_naics = """
SELECT naicscd, naicsdesc, naicstat
FROM capital_iq_data.dbo.r_naiccd
"""

# %%
with con_mssql.connect() as con:
    result = con.execute(text(qry_naics))
    dfnaics = pd.DataFrame(result.fetchall(), columns=result.keys(), dtype='str')

# %%
entries = [tuple(row) for row in dfnaics[['naicscd', 'naicsdesc']].values.tolist()]

# %%
def insert(tree, code, description, level):
    for key in tree:
        if code.startswith(key) and code != key:
            insert(tree[key]['children'], code, description, level + 1)
            return
    tree[code] = {'description': description, 'level': level, 'children': {}}

tree = {}
for code, desc in entries:
    insert(tree, code, desc, 1)

# Flatten the tree
def flatten_tree(tree, parent=None, result=None):
    if result is None:
        result = []
    for code, info in tree.items():
        result.append({'code': code, 'description': info['description'], 'level': info['level'], 'parent': parent})
        flatten_tree(info['children'], parent=code, result=result)
    return result

flat = flatten_tree(tree)
df = pd.DataFrame(flat)

# %%
df.shape
# Out:
# (2919, 4)

# %%
df.head()
# Out:
#      code                                 description  level parent
# 0      11  Agriculture, Forestry, Fishing and Hunting      1   None
# 1     111                             Crop Production      2     11
# 2    1111                   Oilseed and Grain Farming      3    111
# 3   11111                             Soybean Farming      4   1111
# 4  111110                             Soybean Farming      5  11111

# %%
def get_hierarchy(df, code):
    """Return hierarchy as a list of (level, code, description) from first to given level."""
    hierarchy = []
    lookup = df.set_index('code')
    
    while True:
        if code not in lookup.index:
            break
        row = lookup.loc[code]
        # Handle case if multiple rows per code (unlikely here)
        if isinstance(row, pd.DataFrame):
            row = row.iloc[0]
        hierarchy.append((row['level'], code, row['description']))
        if pd.isnull(row['parent']):
            break
        code = row['parent']
    
    return list(reversed(hierarchy))  # First to last

# %%
qry_company = """
SELECT
    cc.companyId, 
    cc.companyName, 
    cicc.industryClassCode as NAICS,
    ccic.industryClassCodeId as capiq_indu_code, 
    cicc.industryClassCodeDesc as indu_desc
FROM
    ciqCompany cc
    JOIN ciqCompanyIndClass ccic ON cc.companyId = ccic.companyId
    JOIN ciqIndustryClassCode cicc ON ccic.industryClassCodeId = cicc.industryClassCodeId
WHERE
    cicc.industryClassTypeId = 416 -- NAICS 
    AND ccic.primaryFlag = 1
"""

# %%
with con_mssql.connect() as con:
    result = con.execute(text(qry_company))
    dfcomp = pd.DataFrame(result.fetchall(), columns=result.keys(), dtype='str')

# %%
dfcomp.shape
# Out:
# (4072805, 5)

# %%
dfcomp.head()
# Out:
#   companyId                     companyName   NAICS capiq_indu_code  \
# 0     18493             DC Venture Partners  523910          106655
# 1     18495         13i Capital Corporation  523910          106655
# 2     18499  21 International Holdings Inc.  513210          106533
# 3     18501            21 Invest Sgr S.p.A.  523910          106655
# 4     18507                   2M Invest A/S  523910          106655
#
#                       indu_desc
# 0  Miscellaneous Intermediation
# 1  Miscellaneous Intermediation
# 2           Software Publishers
# 3  Miscellaneous Intermediation
# 4  Miscellaneous Intermediation

# %%
dfcomp[dfcomp.companyName.str.contains("Samsung")]
# Out:
#           companyId                                        companyName  \
# 6552          91868                      Samsung Electronics Co., Ltd.
# 20098        426807             Samsung Venture Investment Corporation
# 33095        874722                            Samsung C&T Corporation
# 36067        878475                              Samsung SDI Co., Ltd.
# 36158        878587                        Samsung Securities Co.,Ltd.
# ...             ...                                                ...
# 4027697  1896684980                                Samsung Electronics
# 4044157  1939784562     Samsung Special Purpose Acquisition 10 Company
# 4058661  1947958181     Samsung Special Purpose Acquisition 11 Company
# 4070515  1956658702  Samsung Special Purpose Acquisition 12 Company...
# 4072218  1962085119     Samsung Special Purpose Acquisition 13 Company
#
#           NAICS capiq_indu_code  \
# 6552      33441          105866
# 20098    523910          106655
# 33095        42          106038
# 36067     33441          105866
# 36158    523150          106643
# ...         ...             ...
# 4027697  449210         9621181
# 4044157  525990          106697
# 4058661  525990          106697
# 4070515  525990          106697
# 4072218  525990          106697
#
#                                                  indu_desc
# 6552     Semiconductor and Other Electronic Component M...
# 20098                         Miscellaneous Intermediation
# 33095                                      Wholesale Trade
# 36067    Semiconductor and Other Electronic Component M...
# 36158     Investment Banking and Securities Intermediation
# ...                                                    ...
# 4027697                Electronics and Appliance Retailers
# 4044157                           Other Financial Vehicles
# 4058661                           Other Financial Vehicles
# 4070515                           Other Financial Vehicles
# 4072218                           Other Financial Vehicles
#
# [428 rows x 5 columns]

# %%
dfcomp['naics_level'] = dfcomp.apply(lambda x: get_hierarchy(df, x.NAICS), axis=1)

# %%
dfcomp.head()
# Out:
#   companyId                     companyName   NAICS capiq_indu_code  \
# 0     18493             DC Venture Partners  523910          106655
# 1     18495         13i Capital Corporation  523910          106655
# 2     18499  21 International Holdings Inc.  513210          106533
# 3     18501            21 Invest Sgr S.p.A.  523910          106655
# 4     18507                   2M Invest A/S  523910          106655
#
#                       indu_desc  \
# 0  Miscellaneous Intermediation
# 1  Miscellaneous Intermediation
# 2           Software Publishers
# 3  Miscellaneous Intermediation
# 4  Miscellaneous Intermediation
#
#                                          naics_level
# 0  [(1, 52, Finance and Insurance), (2, 523, Secu...
# 1  [(1, 52, Finance and Insurance), (2, 523, Secu...
# 2  [(1, 51, Information), (2, 513, Publishing Ind...
# 3  [(1, 52, Finance and Insurance), (2, 523, Secu...
# 4  [(1, 52, Finance and Insurance), (2, 523, Secu...

# %%
for i in range(5):
    dfcomp[f'naics_level_{i+1}'] = dfcomp['naics_level'].apply(
        lambda x: x[i] if len(x) > i else (None, None, None)
    )

dfcomp['level_1'], dfcomp['code_1'], dfcomp['desc_1'] = zip(*dfcomp['naics_level_1'])
dfcomp['level_2'], dfcomp['code_2'], dfcomp['desc_2'] = zip(*dfcomp['naics_level_2'])
dfcomp['level_3'], dfcomp['code_3'], dfcomp['desc_3'] = zip(*dfcomp['naics_level_3'])
dfcomp['level_4'], dfcomp['code_4'], dfcomp['desc_4'] = zip(*dfcomp['naics_level_4'])
dfcomp['level_5'], dfcomp['code_5'], dfcomp['desc_5'] = zip(*dfcomp['naics_level_5'])

# Optionally, drop the intermediate columns
dfcomp.drop([f'naics_level_{i+1}' for i in range(5)], axis=1, inplace=True)

# %%
dfcomp.head()
# Out:
#   companyId                     companyName   NAICS capiq_indu_code  \
# 0     18493             DC Venture Partners  523910          106655
# 1     18495         13i Capital Corporation  523910          106655
# 2     18499  21 International Holdings Inc.  513210          106533
# 3     18501            21 Invest Sgr S.p.A.  523910          106655
# 4     18507                   2M Invest A/S  523910          106655
#
#                       indu_desc  \
# 0  Miscellaneous Intermediation
# 1  Miscellaneous Intermediation
# 2           Software Publishers
# 3  Miscellaneous Intermediation
# 4  Miscellaneous Intermediation
#
#                                          naics_level  level_1 code_1  \
# 0  [(1, 52, Finance and Insurance), (2, 523, Secu...        1     52
# 1  [(1, 52, Finance and Insurance), (2, 523, Secu...        1     52
# 2  [(1, 51, Information), (2, 513, Publishing Ind...        1     51
# 3  [(1, 52, Finance and Insurance), (2, 523, Secu...        1     52
# 4  [(1, 52, Finance and Insurance), (2, 523, Secu...        1     52
#
#                   desc_1  level_2  ...  \
# 0  Finance and Insurance      2.0  ...
# 1  Finance and Insurance      2.0  ...
# 2            Information      2.0  ...
# 3  Finance and Insurance      2.0  ...
# 4  Finance and Insurance      2.0  ...
#
#                                               desc_2 level_3  code_3  \
# 0  Securities, Commodity Contracts, and Other Fin...     3.0    5239
# 1  Securities, Commodity Contracts, and Other Fin...     3.0    5239
# 2                              Publishing Industries     3.0    5132
# 3  Securities, Commodity Contracts, and Other Fin...     3.0    5239
# 4  Securities, Commodity Contracts, and Other Fin...     3.0    5239
#
#                                   desc_3 level_4  code_4  \
# 0  Other Financial Investment Activities     4.0   52391
# 1  Other Financial Investment Activities     4.0   52391
# 2                    Software Publishers     4.0   51321
# 3  Other Financial Investment Activities     4.0   52391
# 4  Other Financial Investment Activities     4.0   52391
#
#                          desc_4 level_5  code_5                        desc_5
# 0  Miscellaneous Intermediation     5.0  523910  Miscellaneous Intermediation
# 1  Miscellaneous Intermediation     5.0  523910  Miscellaneous Intermediation
# 2           Software Publishers     5.0  513210           Software Publishers
# 3  Miscellaneous Intermediation     5.0  523910  Miscellaneous Intermediation
# 4  Miscellaneous Intermediation     5.0  523910  Miscellaneous Intermediation
#
# [5 rows x 21 columns]

# %%
dfcomp.desc_1.value_counts()
# Out:
# desc_1
# Manufacturing                                                               814219
# Wholesale Trade                                                             648169
# Retail Trade                                                                410474
# Construction                                                                376445
# Finance and Insurance                                                       251205
# Professional, Scientific, and Technical Services                            249506
# Administrative and Support and Waste Management and Remediation Services    176790
# Information                                                                 143987
# Transportation and Warehousing                                              143792
# Health Care and Social Assistance                                           140451
# Real Estate and Rental and Leasing                                          127361
# Management of Companies and Enterprises                                     126819
# Other Services (except Public Administration)                                78467
# Educational Services                                                         65675
# Accommodation and Food Services                                              59181
# Utilities                                                                    55510
# Mining, Quarrying, and Oil and Gas Extraction                                49319
# All Unclassified Establishments                                              42504
# Agriculture, Forestry, Fishing and Hunting                                   38586
# Public Administration                                                        37793
# Arts, Entertainment, and Recreation                                          36552
# Name: count, dtype: int64

# %%
dfcomp.desc_2.value_counts()
# Out:
# desc_2
# Merchant Wholesalers, Durable Goods (eff from 6/15/2002)                         356743
# Merchant Wholesalers, Nondurable Goods (eff from 6/15/2002)                      290373
# Professional, Scientific, and Technical Services                                 249365
# Administrative and Support Services                                              158141
# Construction of Buildings (eff from 6/15/2002)                                   135154
#                                                                                   ...
# Administration of Housing Programs, Urban Planning, and Community Development       685
# Postal Service                                                                      597
# Wholesale Trade Agents and Brokers (eff from 6/15/2002)                             462
# Monetary Authorities-Central Bank                                                   395
# Space Research and Technology                                                       145
# Name: count, Length: 97, dtype: int64

# %%
dfcomp[dfcomp.desc_2 == 'Monetary Authorities-Central Bank'].head()
# Out:
#       companyId                       companyName   NAICS capiq_indu_code  \
# 11980    163065  Federal Reserve Bank of New York  521110          106611
# 32314    873745                   Bank of Finland  521110          106611
# 32355    873803             Central Bank of Egypt  521110          106611
# 32515    874019                 Bank of Mauritius  521110          106611
# 32529    874036               The Bank of England  521110          106611
#
#                                indu_desc  level_1 code_1  \
# 11980  Monetary Authorities-Central Bank        1     52
# 32314  Monetary Authorities-Central Bank        1     52
# 32355  Monetary Authorities-Central Bank        1     52
# 32515  Monetary Authorities-Central Bank        1     52
# 32529  Monetary Authorities-Central Bank        1     52
#
#                       desc_1  level_2 code_2  \
# 11980  Finance and Insurance      2.0    521
# 32314  Finance and Insurance      2.0    521
# 32355  Finance and Insurance      2.0    521
# 32515  Finance and Insurance      2.0    521
# 32529  Finance and Insurance      2.0    521
#
#                                   desc_2  level_3 code_3  \
# 11980  Monetary Authorities-Central Bank      3.0   5211
# 32314  Monetary Authorities-Central Bank      3.0   5211
# 32355  Monetary Authorities-Central Bank      3.0   5211
# 32515  Monetary Authorities-Central Bank      3.0   5211
# 32529  Monetary Authorities-Central Bank      3.0   5211
#
#                                   desc_3  level_4 code_4  \
# 11980  Monetary Authorities-Central Bank      4.0  52111
# 32314  Monetary Authorities-Central Bank      4.0  52111
# 32355  Monetary Authorities-Central Bank      4.0  52111
# 32515  Monetary Authorities-Central Bank      4.0  52111
# 32529  Monetary Authorities-Central Bank      4.0  52111
#
#                                   desc_4  level_5  code_5  \
# 11980  Monetary Authorities-Central Bank      5.0  521110
# 32314  Monetary Authorities-Central Bank      5.0  521110
# 32355  Monetary Authorities-Central Bank      5.0  521110
# 32515  Monetary Authorities-Central Bank      5.0  521110
# 32529  Monetary Authorities-Central Bank      5.0  521110
#
#                                   desc_5
# 11980  Monetary Authorities-Central Bank
# 32314  Monetary Authorities-Central Bank
# 32355  Monetary Authorities-Central Bank
# 32515  Monetary Authorities-Central Bank
# 32529  Monetary Authorities-Central Bank

# %%
dfcomp.shape
# Out:
# (4072805, 20)

# %%
qry_compmeta = """
SELECT 
    cti.tradingItemId, 
    cti.securityId, 
    cs.companyId, 
    ce.exchangeName,
    ce.exchangeSymbol,
    tickerSymbol,
    cc.ISOCode,
    ccg.isoCountry2
FROM ciqTradingItem cti 
    join (
        SELECT cs.securityId, cs.companyId  
        FROM ciqSecurity cs 
        JOIN ciqCompany cc on cc.companyId = cs.companyId
        WHERE cs.securityName = 'Common Stock'
        -- and cc.companyStatusTypeId = 1 -- operating
        -- and cc.companyTypeId = 4 -- public company        
    ) cs on cti.securityId = cs.securityId
    join ciqExchange ce on ce.exchangeId = cti.exchangeId 
    join ciqCurrency cc on cc.currencyId = cti.currencyId 
    join ciqCountryGeo ccg on ccg.countryId  = ce.countryId 
WHERE primaryFlag  = 1 
order by ce.exchangeSymbol
"""

# %%
with con_mssql.connect() as con:
    result = con.execute(text(qry_compmeta))
    dfcompmeta = pd.DataFrame(result.fetchall(), columns=result.keys(), dtype='str')

# %%
dfcompmeta.shape
# Out:
# (38358, 8)

# %%
dfcomp2 = dfcompmeta.merge(dfcomp, on='companyId', how='inner')

# %%
dfcomp2.shape
# Out:
# (28741, 27)

# %%
dfcomp2[dfcomp2.companyName.str.contains("Samsung Electronics")]
# Out:
#      tradingItemId securityId companyId          exchangeName exchangeSymbol  \
# 4195      20242977   20229558     91868  Korea Stock Exchange           KOSE
#
#      tickerSymbol ISOCode isoCountry2                    companyName  NAICS  \
# 4195      A005930     KRW          KR  Samsung Electronics Co., Ltd.  33441
#
#       ...                                         desc_2 level_3  code_3  \
# 4195  ...  Computer and Electronic Product Manufacturing     3.0    3344
#
#                                                  desc_3 level_4  code_4  \
# 4195  Semiconductor and Other Electronic Component M...     4.0   33441
#
#                                                  desc_4 level_5  code_5 desc_5
# 4195  Semiconductor and Other Electronic Component M...     NaN    None   None
#
# [1 rows x 27 columns]

# %%
dfcomp2_kr = dfcomp2[(dfcomp2.isoCountry2 == 'KR') & (dfcomp2.exchangeSymbol.isin(['KOSDAQ', 'KOSE']))].copy()

# %%
chunk_size = 200  # Adjust as needed
lst_dfs = []

trading_item_ids = dfcomp2_kr['tradingItemId'].unique().tolist()

def chunk_list(data, chunk_size):
    for i in range(0, len(data), chunk_size):
        yield data[i:i + chunk_size]

for chunk in tqdm(chunk_list(trading_item_ids, chunk_size), total=(len(trading_item_ids) + chunk_size - 1) // chunk_size, desc="Fetching price data"):
    placeholders = ','.join([str(x) for x in chunk])
    qry_price = f"""
    SELECT tradingItemId, pricingDate, priceOpen, priceHigh, priceLow, priceMid, priceClose, priceBid, priceAsk, volume, adjustmentFactor, VWAP
    FROM capital_iq_data.dbo.ciqPriceEquity
    WHERE tradingItemId IN ({placeholders})
    AND pricingDate > '2015-01-01'
    """
    with con_mssql.connect() as con:
        result = con.execute(text(qry_price))
        df_chunk = pd.DataFrame(result.fetchall(), columns=result.keys())
        lst_dfs.append(df_chunk)

df_price = pd.concat(lst_dfs, ignore_index=True)
# Out:
# Fetching price data: 100%|██████████| 14/14 [01:26<00:00,  6.17s/it]

# %% [markdown]
# #### Market capitalization

# %%
chunk_size = 200  # Adjust as needed
lst_dfs = []

company_ids = dfcomp2_kr['companyId'].unique().tolist()

def chunk_list(data, chunk_size):
    for i in range(0, len(data), chunk_size):
        yield data[i:i + chunk_size]

for chunk in tqdm(chunk_list(company_ids, chunk_size), total=(len(company_ids) + chunk_size - 1) // chunk_size, desc="Fetching market cap data"):
    placeholders = ','.join([str(x) for x in chunk])
    qry_marketcap = f"""
    SELECT companyId, pricingDate, marketCap, TEV, sharesOutstanding
    FROM capital_iq_data.dbo.ciqMarketCap
    WHERE companyId IN ({placeholders})
    AND pricingDate > '2015-01-01'
    """
    with con_mssql.connect() as con:
        result = con.execute(text(qry_marketcap))
        df_chunk = pd.DataFrame(result.fetchall(), columns=result.keys())
        lst_dfs.append(df_chunk)

df_marketcap = pd.concat(lst_dfs, ignore_index=True)
# Out:
# Fetching market cap data: 100%|██████████| 14/14 [00:45<00:00,  3.24s/it]

# %%
df_marketcap.shape
# Out:
# (7397243, 5)

# %%
df_price.shape
# Out:
# (4823366, 12)

# %%
caqiq_data_dir = r'L:\DRS\Projects\2025_drs_ai\capiq'

# %%
df_price.to_parquet(os.path.join(caqiq_data_dir, 'capiq_price_equity_kr.parquet'), index=False)

# %%
dfcomp.to_parquet(os.path.join(caqiq_data_dir, 'comp_naics_code_all.parquet'))

# %%
dfcomp2.to_parquet(os.path.join(caqiq_data_dir, 'comp_naics_code_common_stock.parquet'))

# %%
df_marketcap.head(2)
# Out:
#    companyId pricingDate      marketCap            TEV  sharesOutstanding
# 0    7672534  2025-01-24  141108.609600  101429.029260           13065612
# 1    7672534  2025-01-25  141108.609600  101429.029260           13065612

# %%
df_marketcap.to_parquet(os.path.join(caqiq_data_dir, 'capiq_marketcap_kr.parquet'), index=False, engine='fastparquet')

# %%
# dfcomp2 = pd.read_parquet(os.path.join(caqiq_data_dir, 'comp_naics_code_common_stock.parquet'), engine='fastparquet')
# df_price = pd.read_parquet(os.path.join(caqiq_data_dir, 'capiq_price_equity_kr.parquet'), engine='fastparquet')
